# %%
import pandas as pd

# %%
df = pd.read_csv('WorldCupMatches.csv', index_col=2)

# %%
df.head(10)
# Out:
#            Year              Datetime             Stadium         City  \
# Stage
# Group 1  1930.0  13 Jul 1930 - 15:00              Pocitos  Montevideo
# Group 4  1930.0  13 Jul 1930 - 15:00       Parque Central  Montevideo
# Group 2  1930.0  14 Jul 1930 - 12:45       Parque Central  Montevideo
# Group 3  1930.0  14 Jul 1930 - 14:50              Pocitos  Montevideo
# Group 1  1930.0  15 Jul 1930 - 16:00       Parque Central  Montevideo
# Group 1  1930.0  16 Jul 1930 - 14:45       Parque Central  Montevideo
# Group 2  1930.0  17 Jul 1930 - 12:45       Parque Central  Montevideo
# Group 4  1930.0  17 Jul 1930 - 14:45       Parque Central  Montevideo
# Group 3  1930.0  18 Jul 1930 - 14:30   Estadio Centenario  Montevideo
# Group 1  1930.0  19 Jul 1930 - 12:50   Estadio Centenario  Montevideo
#
#         Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# Stage
# Group 1         France              4.0              1.0         Mexico
# ...

# %%
df.dropna() #drop duplicated rows
# Out:
#                             Year              Datetime              Stadium  \
# Stage
# Group 1                   1930.0  13 Jul 1930 - 15:00               Pocitos
# Group 4                   1930.0  13 Jul 1930 - 15:00        Parque Central
# Group 2                   1930.0  14 Jul 1930 - 12:45        Parque Central
# Group 3                   1930.0  14 Jul 1930 - 14:50               Pocitos
# Group 1                   1930.0  15 Jul 1930 - 16:00        Parque Central
# ...                          ...                   ...                  ...
# Quarter-finals            2014.0  05 Jul 2014 - 17:00      Arena Fonte Nova
# Semi-finals               2014.0  08 Jul 2014 - 17:00      Estadio Mineirao
# Semi-finals               2014.0  09 Jul 2014 - 17:00    Arena de Sao Paulo
# Play-off for third place  2014.0  12 Jul 2014 - 17:00      Estadio Nacional
# Final                     2014.0  13 Jul 2014 - 16:00   Estadio do Maracana
#
# ...

# %%
df.iloc[3:]
# Out:
#            Year              Datetime         Stadium         City  \
# Stage
# Group 3  1930.0  14 Jul 1930 - 14:50          Pocitos  Montevideo
# Group 1  1930.0  15 Jul 1930 - 16:00   Parque Central  Montevideo
# Group 1  1930.0  16 Jul 1930 - 14:45   Parque Central  Montevideo
# Group 2  1930.0  17 Jul 1930 - 12:45   Parque Central  Montevideo
# Group 4  1930.0  17 Jul 1930 - 14:45   Parque Central  Montevideo
# ...         ...                   ...             ...          ...
# NaN         NaN                   NaN             NaN          NaN
# NaN         NaN                   NaN             NaN          NaN
# NaN         NaN                   NaN             NaN          NaN
# NaN         NaN                   NaN             NaN          NaN
# NaN         NaN                   NaN             NaN          NaN
#
#         Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# Stage
# Group 3        Romania              3.0              1.0           Peru
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('WorldCupMatches.csv', index_col=2, header=0)

# %%
df.dtypes
# Out:
# Datetime           object
# Stage              object
# Stadium            object
# City               object
# Home Team Name     object
# Away Team Name     object
# Win conditions     object
# Attendance        float64
# dtype: object

# %%
df2= pd.read_csv('WorldCupMatches.csv', usecols=[1,2,3,4,5,8,9,10]) #filtering columns

# %%
df2
# Out:
#                   Datetime    Stage         Stadium         City  \
# 0     13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1     13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2     14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3     14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4     15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
# ...                    ...      ...             ...          ...
# 4567                   NaN      NaN             NaN          NaN
# 4568                   NaN      NaN             NaN          NaN
# 4569                   NaN      NaN             NaN          NaN
# 4570                   NaN      NaN             NaN          NaN
# 4571                   NaN      NaN             NaN          NaN
#
#      Home Team Name Away Team Name Win conditions  Attendance
# 0            France         Mexico                     4444.0
# 1               USA        Belgium                    18346.0
# ...

# %%
df2 = pd.read_csv('WorldCupMatches.csv', dtype = {'Winconditions':'bool'}, usecols=[1,3,5,6,7,8,9,10])

# %%
df2.head(10)
# Out:
#                Datetime             Stadium Home Team Name  Home Team Goals  \
# 0  13 Jul 1930 - 15:00              Pocitos         France              4.0
# 1  13 Jul 1930 - 15:00       Parque Central            USA              3.0
# 2  14 Jul 1930 - 12:45       Parque Central     Yugoslavia              2.0
# 3  14 Jul 1930 - 14:50              Pocitos        Romania              3.0
# 4  15 Jul 1930 - 16:00       Parque Central      Argentina              1.0
# 5  16 Jul 1930 - 14:45       Parque Central          Chile              3.0
# 6  17 Jul 1930 - 12:45       Parque Central     Yugoslavia              4.0
# 7  17 Jul 1930 - 14:45       Parque Central            USA              3.0
# 8  18 Jul 1930 - 14:30   Estadio Centenario        Uruguay              1.0
# 9  19 Jul 1930 - 12:50   Estadio Centenario          Chile              1.0
#
#    Away Team Goals Away Team Name Win conditions  Attendance
# 0              1.0         Mexico                     4444.0
# ...

# %%
df2.shape # rows and columns
# Out:
# (4572, 8)

# %%
df2.count() #missing data check
# Out:
# Year                    852
# Datetime                852
# Stage                   852
# Stadium                 852
# City                    852
# Home Team Name          852
# Home Team Goals         852
# Away Team Goals         852
# Away Team Name          852
# Win conditions          852
# Attendance              850
# Half-time Home Goals    852
# Half-time Away Goals    852
# Referee                 852
# Assistant 1             852
# Assistant 2             852
# RoundID                 852
# MatchID                 852
# Home Team Initials      852
# Away Team Initials      852
# dtype: int64

# %%
df2.isnull().sum()
# Out:
# Year                    3720
# Datetime                3720
# Stage                   3720
# Stadium                 3720
# City                    3720
# Home Team Name          3720
# Home Team Goals         3720
# Away Team Goals         3720
# Away Team Name          3720
# Win conditions          3720
# Attendance              3722
# Half-time Home Goals    3720
# Half-time Away Goals    3720
# Referee                 3720
# Assistant 1             3720
# Assistant 2             3720
# RoundID                 3720
# MatchID                 3720
# Home Team Initials      3720
# Away Team Initials      3720
# dtype: int64

# %%
df2.dropna() #drop missing values
# Out:
#        Year              Datetime                     Stage  \
# 0    1930.0  13 Jul 1930 - 15:00                    Group 1
# 1    1930.0  13 Jul 1930 - 15:00                    Group 4
# 2    1930.0  14 Jul 1930 - 12:45                    Group 2
# 3    1930.0  14 Jul 1930 - 14:50                    Group 3
# 4    1930.0  15 Jul 1930 - 16:00                    Group 1
# ..      ...                   ...                       ...
# 847  2014.0  05 Jul 2014 - 17:00             Quarter-finals
# 848  2014.0  08 Jul 2014 - 17:00                Semi-finals
# 849  2014.0  09 Jul 2014 - 17:00                Semi-finals
# 850  2014.0  12 Jul 2014 - 17:00   Play-off for third place
# 851  2014.0  13 Jul 2014 - 16:00                      Final
#
#                  Stadium             City Home Team Name  Home Team Goals  \
# 0                Pocitos      Montevideo          France              4.0
# 1         Parque Central      Montevideo             USA              3.0
# ...

# %%
df2.shape
# Out:
# (4572, 20)

# %%
df.loc[df2.duplicated(keep=False), :] # loc based on labels
# Out:
#                   Datetime           Stage              Stadium  \
# 820   28 Jun 2014 - 13:00      Round of 16     Estadio Mineirao
# 821   28 Jun 2014 - 17:00      Round of 16  Estadio do Maracana
# 822   30 Jun 2014 - 13:00      Round of 16     Estadio Nacional
# 823   30 Jun 2014 - 17:00      Round of 16    Estadio Beira-Rio
# 824   04 Jul 2014 - 17:00   Quarter-finals     Estadio Castelao
# ...                    ...             ...                  ...
# 4567                   NaN             NaN                  NaN
# 4568                   NaN             NaN                  NaN
# 4569                   NaN             NaN                  NaN
# 4570                   NaN             NaN                  NaN
# 4571                   NaN             NaN                  NaN
#
#                  City Home Team Name Away Team Name  \
# 820   Belo Horizonte          Brazil          Chile
# 821   Rio De Janeiro        Colombia        Uruguay
# ...

# %%
df2.drop_duplicates() #drops duplicated rows
# Out:
#                  Datetime             Stadium Home Team Name  Home Team Goals  \
# 0    13 Jul 1930 - 15:00              Pocitos         France              4.0
# 1    13 Jul 1930 - 15:00       Parque Central            USA              3.0
# 2    14 Jul 1930 - 12:45       Parque Central     Yugoslavia              2.0
# 3    14 Jul 1930 - 14:50              Pocitos        Romania              3.0
# 4    15 Jul 1930 - 16:00       Parque Central      Argentina              1.0
# ..                    ...                 ...            ...              ...
# 832  29 Jun 2014 - 13:00     Estadio Castelao    Netherlands              2.0
# 833  29 Jun 2014 - 17:00     Arena Pernambuco     Costa Rica              1.0
# 834  01 Jul 2014 - 13:00   Arena de Sao Paulo      Argentina              1.0
# 835  01 Jul 2014 - 17:00     Arena Fonte Nova        Belgium              2.0
# 852                   NaN                 NaN            NaN              NaN
#
# ...

# %%
df2.fillna(0) #all missing values replaced by number in brackets
# Out:
#                   Datetime         Stadium Home Team Name  Home Team Goals  \
# 0     13 Jul 1930 - 15:00          Pocitos         France              4.0
# 1     13 Jul 1930 - 15:00   Parque Central            USA              3.0
# 2     14 Jul 1930 - 12:45   Parque Central     Yugoslavia              2.0
# 3     14 Jul 1930 - 14:50          Pocitos        Romania              3.0
# 4     15 Jul 1930 - 16:00   Parque Central      Argentina              1.0
# ...                    ...             ...            ...              ...
# 4567                     0               0              0              0.0
# 4568                     0               0              0              0.0
# 4569                     0               0              0              0.0
# 4570                     0               0              0              0.0
# 4571                     0               0              0              0.0
#
#       Away Team Goals Away Team Name Win conditions  Attendance
# ...
